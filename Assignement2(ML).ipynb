# %% [markdown]
# <a href="https://colab.research.google.com/github/sreepuli/Basic-machinelearning/blob/main/Assignement2(ML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.creating DataFrames

# %% [markdown]
# Create a Pandas DataFrame from the following dictionary:
# data = {
# 'Name': ['Alice', 'Bob', 'Carol'],
# 'Age': [24, 27, 22],
# 'Salary': [50000, 55000, 48000]
# }
# • Add a new column called Bonus which is 10% of the salary.

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Name':['Alice','Bob','Carol'],
                 'Age':[24,27,22],
                 'Salary':[50000,55000,48000]})
df['Bonus']=df['Salary']*0.1
df
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0
# 2  Carol   22   48000  4800.0

# %% [markdown]
# #2.Display the first two rows.

# %%
df.head(2)
# Out:
#     Name  Age  Salary   Bonus
# 0  Alice   24   50000  5000.0
# 1    Bob   27   55000  5500.0

# %% [markdown]
# #2b.Compute the mean salary.

# %%
df['Salary'].mean()
# Out:
# 51000.0

# %% [markdown]
# #3a.Extract all rows where the Age is greater than 25.

# %%
df[df['Age']>25]
# Out:
#   Name  Age  Salary   Bonus
# 1  Bob   27   55000  5500.0

# %% [markdown]
# #3b.Filter out rows where the Salary is less than 50000.

# %%
df[df['Salary']>50000]
# Out:
#   Name  Age  Salary   Bonus
# 1  Bob   27   55000  5500.0

# %% [markdown]
# #4a.Fill missing values in column A with the mean of the column.

# %%
data = {
'A': [1, 2, None, 4],
'B': [None, 2, 3, None],
'C': [1, 2, 3, 4]
}
df = pd.DataFrame(data)
mean_a = df['A'].mean()
df['A'] = df['A'].fillna(mean_a)
mean_a
df
# Out:
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4

# %% [markdown]
# #4b.Drop rows where all values are None.

# %%
df=df.dropna(how='all')
df
# Out:
#           A    B  C
# 0  1.000000  NaN  1
# 1  2.000000  2.0  2
# 2  2.333333  3.0  3
# 3  4.000000  NaN  4

# %% [markdown]
# #5.Group the data by Department and compute the total and mean salary for each department.

# %%
data = {
'Department': ['HR', 'HR', 'IT', 'IT', 'Finance'],
'Employee': ['Alice', 'Bob', 'Carol', 'David', 'Eve'],
'Salary': [50000, 45000, 60000, 65000, 70000] }
df = pd.DataFrame(data)
df.groupby('Department')
df.groupby('Department').agg({'Salary':['sum','mean']})
# Out:
#             Salary
#                sum     mean
# Department
# Finance      70000  70000.0
# HR           95000  47500.0
# IT          125000  62500.0

# %% [markdown]
# #6.Perform an inner join on the ID column.

# %%
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Carol']})
df2 = pd.DataFrame({'ID': [2, 3, 4], 'Age': [25, 30, 22]})
pd.merge(df1, df2, on='ID')
# Out:
#    ID   Name  Age
# 0   2    Bob   25
# 1   3  Carol   30

# %% [markdown]
# #7.Given a small dataset, clean and display basic statistics using Pandas.

# %%
df.to_csv('my_data.csv', index=False)

# %%
df1=pd.read_csv('my_data.csv')
df1
# Out:
#   Department Employee  Salary
# 0         HR    Alice   50000
# 1         HR      Bob   45000
# 2         IT    Carol   60000
# 3         IT    David   65000
# 4    Finance      Eve   70000

# %%
df1.describe()
# Out:
#              Salary
# count      5.000000
# mean   58000.000000
# std    10368.220677
# min    45000.000000
# 25%    50000.000000
# 50%    60000.000000
# 75%    65000.000000
# max    70000.000000

# %% [markdown]
# #8.small EDA task

# %% [markdown]
# Load the Titanic dataset (titanic.csv) into a Pandas DataFrame.

# %%
import matplotlib.pyplot as plt

# %%
df2=pd.read_csv('/content/Titanic-Dataset.csv')
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("Missing values in each column:")
print(df2.isnull().sum())
# Out:
# Missing values in each column:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
average_age = df2['Age'].mean()
print(f"Average age of passengers: {average_age:.2f}")
# Out:
# Average age of passengers: 29.70

# %%
survival_rate_gender = df.groupby('Sex')['Survived'].mean()

# %%
survival_rate_gender.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Survival Rate Based on Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #9.Data Transformation

# %% [markdown]
# Load a dataset containing daily temperatures and dates

# %%
df3=pd.read_csv('/content/DailyDelhiClimateTest.csv')
df3
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure
# 0    2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1    2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2    2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3    2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4    2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..          ...        ...        ...         ...           ...
# 109  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
df3['date'] = pd.to_datetime(df3['date'])
def categorize_temperature(meantemp):
    if meantemp >= 30:
        return 'High'
    elif meantemp >= 15:
        return 'Medium'
    else:
        return 'Low'

df3['Temp_Category'] = df3['meantemp'].apply(categorize_temperature)

# Display the transformed data
print(df3.sample(10))
# Out:
#           date   meantemp   humidity  wind_speed  meanpressure Temp_Category
# 40  2017-02-10  14.666667  71.777778    9.066667   1015.666667           Low
# 52  2017-02-22  19.125000  57.125000    7.412500   1012.250000        Medium
# 36  2017-02-06  16.888889  69.666667    9.044444   1016.000000        Medium
# 109 2017-04-20  34.500000  27.500000    5.562500    998.625000          High
# 24  2017-01-25  21.000000  69.960000    8.756000   1018.400000        Medium
# 29  2017-01-30  16.444444  77.555556    4.322222   1015.833333        Medium
# 60  2017-03-02  23.750000  54.250000    5.930000   1012.150000        Medium
# 48  2017-02-18  21.125000  70.750000    6.250000   1016.250000        Medium
# 55  2017-02-25  19.000000  50.428571   11.928571   1014.285714        Medium
# 35  2017-02-05  18.631579  77.631579    8.100000   1014.210526        Medium
